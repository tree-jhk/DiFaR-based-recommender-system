# %%
import pandas as pd

# %%
ml_m = pd.read_csv("./data/ml-20m/movies.csv")
ml_r = pd.read_csv("./data/ml-20m/ratings.csv")

# %%
ml_m.sample(1)
# Out:
#       movieId                           title                 genres
# 7300     7412  Cat and the Canary, The (1978)  Comedy|Horror|Mystery

# %%
ml_r.sample(1)
# Out:
#          userId  movieId  rating   timestamp
# 9475061   65529      346     1.0  1296711070

# %%
# TODO: MovieLens single KG
'''
User: userId
Item: movieId & title
Attributes: genres, release_year
Relation: rating
'''
ml_kg = pd.merge(ml_r, ml_m, on=["movieId"], how="inner")

# %%
ml_kg.drop(labels=["timestamp"], axis=1, inplace=True)

# %%
ml_kg
# Out:
#           userId  movieId  rating  \
# 0              1        2     3.5
# 1              5        2     3.0
# 2             13        2     3.0
# 3             29        2     3.0
# 4             34        2     3.0
# ...          ...      ...     ...
# 20000258  138301   121017     3.5
# 20000259  138301   121019     4.5
# 20000260  138301   121021     4.5
# 20000261  138406   110167     4.5
# 20000262  138406   110510     4.5
#
#                                                       title  \
# 0                                            Jumanji (1995)
# 1                                            Jumanji (1995)
# 2                                            Jumanji (1995)
# 3                                            Jumanji (1995)
# 4                                            Jumanji (1995)
# ...                                                     ...
# 20000258                    The Gentleman from Epsom (1962)
# 20000259                         The Great Spy Chase (1964)
# 20000260                             Taxi for Tobruk (1961)
# 20000261  Judge and the Assassin, The (Juge et l'assassi...
# 20000262                                 Série noire (1979)
#
#                               genres
# 0         Adventure|Children|Fantasy
# 1         Adventure|Children|Fantasy
# 2         Adventure|Children|Fantasy
# 3         Adventure|Children|Fantasy
# 4         Adventure|Children|Fantasy
# ...                              ...
# 20000258                Comedy|Crime
# 20000259      Action|Comedy|Thriller
# 20000260                   Drama|War
# 20000261                 Crime|Drama
# 20000262                   Film-Noir
#
# [20000263 rows x 5 columns]

# %%
ml_kg = ml_kg[~ml_kg["title"].str.contains(r"1975-1979", regex=True)]

# %%
ml_kg = ml_kg[~ml_kg["title"].str.contains(r"2007-", regex=True)]

# %%
ml_kg[ml_kg["title"].str.contains(r"Frankenstein$", regex=True)]
# Out:
#           userId  movieId  rating                                title  \
# 19957051   11288   115685     4.0  National Theatre Live: Frankenstein
# 19957052   32632   115685     5.0  National Theatre Live: Frankenstein
# 19957053   42506   115685     4.5  National Theatre Live: Frankenstein
# 19957054   90256   115685     5.0  National Theatre Live: Frankenstein
# 19957055  111963   115685     4.0  National Theatre Live: Frankenstein
# 19957056  119157   115685     1.0  National Theatre Live: Frankenstein
# 19957057  119465   115685     0.5  National Theatre Live: Frankenstein
#
#                  genres
# 19957051  Drama|Fantasy
# 19957052  Drama|Fantasy
# 19957053  Drama|Fantasy
# 19957054  Drama|Fantasy
# 19957055  Drama|Fantasy
# 19957056  Drama|Fantasy
# 19957057  Drama|Fantasy

# %%
def get_year(x:str):
    try:
        return str(int(x.split()[-1].strip("\(").strip("\)")) // 10 * 10) + "\'s"
    except:
        return ""

ml_kg["release_year"] = ml_kg["title"].apply(lambda x:get_year(x))

# %%
def p_title(x:str):
    try:
        return " ".join(x.split()[:-1])
    except:
        return x

ml_kg["title"] = ml_kg["title"].apply(lambda x:p_title(x))

# %%
ml_kg['genres'] = ml_kg['genres'].str.split("|")

# %%
ml_kg_neo4j_data = ml_kg.explode('genres')

# %%
ml_kg_neo4j_data.genres.unique()
# Out:
# array(['Adventure', 'Children', 'Fantasy', 'Drama', 'Mystery', 'Sci-Fi',
#        'Thriller', 'Crime', 'Action', 'Comedy', 'Romance', 'War',
#        'Horror', 'Musical', 'Western', 'Animation', 'IMAX', 'Film-Noir',
#        'Documentary', '(no genres listed)'], dtype=object)

# %%
ml_kg_neo4j_data.sort_values(by=["userId", "movieId", "rating"], ascending=(True, True, False), inplace=True)

# %%
ml_kg_neo4j_data["userId"] = ml_kg_neo4j_data["userId"].apply(lambda x:"ML_" + str(x))

# %%
ml_kg_neo4j_data
# Out:
#              userId  movieId  rating  \
# 0              ML_1        2     3.5
# 0              ML_1        2     3.5
# 0              ML_1        2     3.5
# 22243          ML_1       29     3.5
# 22243          ML_1       29     3.5
# ...             ...      ...     ...
# 17724424  ML_138493    69644     3.0
# 13662983  ML_138493    70286     5.0
# 13662983  ML_138493    70286     5.0
# 13662983  ML_138493    70286     5.0
# 17788984  ML_138493    71619     2.5
#
#                                                       title     genres  \
# 0                                                   Jumanji  Adventure
# 0                                                   Jumanji   Children
# 0                                                   Jumanji    Fantasy
# 22243     City of Lost Children, The (Cité des enfants p...  Adventure
# 22243     City of Lost Children, The (Cité des enfants p...      Drama
# ...                                                     ...        ...
# 17724424                     Ice Age: Dawn of the Dinosaurs    Romance
# 13662983                                         District 9    Mystery
# 13662983                                         District 9     Sci-Fi
# 13662983                                         District 9   Thriller
# 17788984             Coco Before Chanel (Coco avant Chanel)      Drama
#
#          release_year
# 0              1990's
# 0              1990's
# 0              1990's
# 22243          1990's
# 22243          1990's
# ...               ...
# 17724424       2000's
# 13662983       2000's
# 13662983       2000's
# 13662983       2000's
# 17788984       2000's
#
# [53176746 rows x 6 columns]

# %%
ratio = 0.1

import random
random.seed(1004)

uid_list = list(ml_kg_neo4j_data.userId.unique())

sample_uid_list = random.sample(uid_list, round(len(uid_list) * ratio))

sampled_ml_kg = ml_kg_neo4j_data[ml_kg_neo4j_data['userId'].isin(sample_uid_list)]

sampled_ml_kg
# Out:
#              userId  movieId  rating                               title  \
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# ...             ...      ...     ...                                 ...
# 16730404  ML_138471    97913     3.5                      Wreck-It Ralph
# 16730404  ML_138471    97913     3.5                      Wreck-It Ralph
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
#
#              genres release_year
# 3070000   Adventure       1990's
# 3070000   Animation       1990's
# 3070000    Children       1990's
# 3070000      Comedy       1990's
# 3070000     Fantasy       1990's
# ...             ...          ...
# 16730404  Animation       2010's
# 16730404     Comedy       2010's
# 13772847  Adventure       2010's
# 13772847    Fantasy       2010's
# 13772847       IMAX       2010's
#
# [5343578 rows x 6 columns]

# %%
sampled_ml_kg.to_csv("./data/ml_kg_neo4j_data.csv", index=False)

# %%
ratio = 0.00004

# %%
import random
random.seed(1004)

uid_list = list(ml_kg_neo4j_data.userId.unique())

sample_uid_list = random.sample(uid_list, round(len(uid_list) * ratio))

# %%
sample_ml_kg_neo4j_data = ml_kg_neo4j_data[ml_kg_neo4j_data['userId'].isin(sample_uid_list)]

# %%
sample_ml_kg_neo4j_data
# Out:
#              userId  movieId  rating  \
# 3079982    ML_27876        1     3.0
# 3079982    ML_27876        1     3.0
# 3079982    ML_27876        1     3.0
# 3079982    ML_27876        1     3.0
# 3079982    ML_27876        1     3.0
# ...             ...      ...     ...
# 15856287  ML_133396    51255     4.5
# 13725867  ML_133396    81834     5.0
# 13725867  ML_133396    81834     5.0
# 13725867  ML_133396    81834     5.0
# 13725867  ML_133396    81834     5.0
#
#                                                  title     genres release_year
# 3079982                                      Toy Story  Adventure       1990's
# 3079982                                      Toy Story  Animation       1990's
# 3079982                                      Toy Story   Children       1990's
# 3079982                                      Toy Story     Comedy       1990's
# 3079982                                      Toy Story    Fantasy       1990's
# ...                                                ...        ...          ...
# 15856287                                      Hot Fuzz    Mystery       2000's
# 13725867  Harry Potter and the Deathly Hallows: Part 1     Action       2010's
# 13725867  Harry Potter and the Deathly Hallows: Part 1  Adventure       2010's
# 13725867  Harry Potter and the Deathly Hallows: Part 1    Fantasy       2010's
# 13725867  Harry Potter and the Deathly Hallows: Part 1       IMAX       2010's
#
# [1449 rows x 6 columns]

# %%
sample_ml_kg_neo4j_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1449 entries, 3079982 to 13725867
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userId        1449 non-null   object
#  1   movieId       1449 non-null   int64
#  2   rating        1449 non-null   float64
#  3   title         1449 non-null   object
#  4   genres        1449 non-null   object
#  5   release_year  1449 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 79.2+ KB

# %%
sample_ml_kg_neo4j_data.to_csv("./data/sample_ml_kg_neo4j_data.csv", index=False)

# %%
movielens_tmdb_df = pd.read_csv("./data/movielens_tmdb.csv")

# %%
movielens_tmdb_df.sample(1)
# Out:
#        movieId              title  release_year origin_country       Writer  \
# 27479    69744  The Dark Backward        1991.0           Null  Adam Rifkin
#
#       Original Story Original Film Writer     Director        cast
# 27479            NaN                  NaN  Adam Rifkin  James Caan

# %%
sampled_ml_kg
# Out:
#              userId  movieId  rating                               title  \
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# 3070000        ML_6        1     5.0                           Toy Story
# ...             ...      ...     ...                                 ...
# 16730404  ML_138471    97913     3.5                      Wreck-It Ralph
# 16730404  ML_138471    97913     3.5                      Wreck-It Ralph
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 13772847  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
#
#              genres release_year
# 3070000   Adventure       1990's
# 3070000   Animation       1990's
# 3070000    Children       1990's
# 3070000      Comedy       1990's
# 3070000     Fantasy       1990's
# ...             ...          ...
# 16730404  Animation       2010's
# 16730404     Comedy       2010's
# 13772847  Adventure       2010's
# 13772847    Fantasy       2010's
# 13772847       IMAX       2010's
#
# [5343578 rows x 6 columns]

# %%
mt_kg_neo4j_data = pd.read_csv("./data/mt_kg_neo4j_data.csv")
sampled_ml_kg_neo4j_data = pd.read_csv("./data/ml_kg_neo4j_data.csv")
ym_kg_neo4j_data = pd.read_csv("./data/ym_kg_neo4j_data.csv")

# %%
ml_left_join_else_data = pd.merge(sampled_ml_kg_neo4j_data, mt_kg_neo4j_data, on=["title", "release_year"], how="left", suffixes=("_ml", "_mt"))

# %%
ml_left_join_else_data = ml_left_join_else_data[["userId_ml", "movieId_ml", "rating_ml", "title", "genres_ml", "genres_mt", "release_year"]]

# %%
ml_left_join_else_data
# Out:
#            userId_ml  movieId_ml  rating_ml  \
# 0               ML_6           1        5.0
# 1               ML_6           1        5.0
# 2               ML_6           1        5.0
# 3               ML_6           1        5.0
# 4               ML_6           1        5.0
# ...              ...         ...        ...
# 413509765  ML_138471       97913        3.5
# 413509766  ML_138471       97913        3.5
# 413509767  ML_138471       98809        3.5
# 413509768  ML_138471       98809        3.5
# 413509769  ML_138471       98809        3.5
#
#                                         title  genres_ml  genres_mt  \
# 0                                   Toy Story  Adventure  Animation
# 1                                   Toy Story  Adventure  Adventure
# 2                                   Toy Story  Adventure     Comedy
# 3                                   Toy Story  Adventure     Family
# 4                                   Toy Story  Adventure    Fantasy
# ...                                       ...        ...        ...
# 413509765                      Wreck-It Ralph     Comedy     Comedy
# 413509766                      Wreck-It Ralph     Comedy     Family
# 413509767  Hobbit: An Unexpected Journey, The  Adventure        NaN
# 413509768  Hobbit: An Unexpected Journey, The    Fantasy        NaN
# 413509769  Hobbit: An Unexpected Journey, The       IMAX        NaN
#
#           release_year
# 0               1990's
# 1               1990's
# 2               1990's
# 3               1990's
# 4               1990's
# ...                ...
# 413509765       2010's
# 413509766       2010's
# 413509767       2010's
# 413509768       2010's
# 413509769       2010's
#
# [413509770 rows x 7 columns]

# %%
ml_left_join_else_data.userId_ml.nunique()
# Out:
# 13849

# %%
ml_left_join_else_data.movieId_ml.nunique()
# Out:
# 17045

# %%
ml_left_join_else_data.drop_duplicates(subset=["userId_ml", "movieId_ml"])
# 전체 20M 중에서 sampling한 interaction 수
# Out:
#            userId_ml  movieId_ml  rating_ml  \
# 0               ML_6           1        5.0
# 1400            ML_6           3        3.0
# 1404            ML_6           7        5.0
# 1420            ML_6          17        5.0
# 1440            ML_6          52        5.0
# ...              ...         ...        ...
# 413500883  ML_138471       91630        4.0
# 413501539  ML_138471       94780        4.0
# 413502799  ML_138471       95167        4.0
# 413506111  ML_138471       97913        3.5
# 413509767  ML_138471       98809        3.5
#
#                                           title  genres_ml  genres_mt  \
# 0                                     Toy Story  Adventure  Animation
# 1400                           Grumpier Old Men     Comedy     Comedy
# 1404                                    Sabrina     Comedy     Comedy
# 1420                      Sense and Sensibility      Drama      Drama
# 1440                           Mighty Aphrodite     Comedy     Comedy
# ...                                         ...        ...        ...
# 413500883  Mission: Impossible - Ghost Protocol     Action     Action
# 413501539           Snow White and the Huntsman     Action     Action
# 413502799                                 Brave     Action  Animation
# 413506111                        Wreck-It Ralph  Animation  Animation
# 413509767    Hobbit: An Unexpected Journey, The  Adventure        NaN
#
#           release_year
# 0               1990's
# 1400            1990's
# 1404            1990's
# 1420            1990's
# 1440            1990's
# ...                ...
# 413500883       2010's
# 413501539       2010's
# 413502799       2010's
# 413506111       2010's
# 413509767       2010's
#
# [2009475 rows x 7 columns]

# %%
ml_left_join_else_data = ml_left_join_else_data.rename(columns={"userId_ml":"userId", "movieId_ml":"movieId", "rating_ml":"rating"})

# %%
ml_left_join_else_data
# Out:
#               userId  movieId  rating                               title  \
# 0               ML_6        1     5.0                           Toy Story
# 1               ML_6        1     5.0                           Toy Story
# 2               ML_6        1     5.0                           Toy Story
# 3               ML_6        1     5.0                           Toy Story
# 4               ML_6        1     5.0                           Toy Story
# ...              ...      ...     ...                                 ...
# 413509765  ML_138471    97913     3.5                      Wreck-It Ralph
# 413509766  ML_138471    97913     3.5                      Wreck-It Ralph
# 413509767  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 413509768  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
# 413509769  ML_138471    98809     3.5  Hobbit: An Unexpected Journey, The
#
#            genres_ml  genres_mt release_year
# 0          Adventure  Animation       1990's
# 1          Adventure  Adventure       1990's
# 2          Adventure     Comedy       1990's
# 3          Adventure     Family       1990's
# 4          Adventure    Fantasy       1990's
# ...              ...        ...          ...
# 413509765     Comedy     Comedy       2010's
# 413509766     Comedy     Family       2010's
# 413509767  Adventure        NaN       2010's
# 413509768    Fantasy        NaN       2010's
# 413509769       IMAX        NaN       2010's
#
# [413509770 rows x 7 columns]

# %%
ml_left_join_else_data.drop_duplicates(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/compu/KJH/정보과학회/movie_lens.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B165.246.44.238/home/compu/KJH/%EC%A0%95%EB%B3%B4%EA%B3%BC%ED%95%99%ED%9A%8C/movie_lens.ipynb#X50sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ml_left_join_else_data.drop_duplicates(inplace=True)
#
# File /compuworks/anaconda3/envs/kjh/lib/python3.9/site-packages/pandas/core/frame.py:6522, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6519 inplace = validate_bool_kwarg(inplace, "inplace")
#    6520 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6522 result = self[-self.duplicated(subset, keep=keep)]
#    6523 if ignore_index:
#    6524     result.index = default_index(len(result))
#
# File /compuworks/anaconda3/envs/kjh/lib/python3.9/site-packages/pandas/core/frame.py:6662, in DataFrame.duplicated(self, subset, keep)
#    6660 else:
#    6661     vals = (col.values for name, col in self.items() if name in subset)
# -> 6662     labels, shape = map(list, zip(*map(f, vals)))
#    6664     ids = get_group_index(
#    6665         labels,
#    6666         # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6670         xnull=False,
#    6671     )
#    6672     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File /compuworks/anaconda3/envs/kjh/lib/python3.9/site-packages/pandas/core/frame.py:6630, in DataFrame.duplicated.<locals>.f(vals)
#    6629 def f(vals) -> tuple[np.ndarray, int]:
# -> 6630     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6631     return labels.astype("i8", copy=False), len(shape)
#
# File /compuworks/anaconda3/envs/kjh/lib/python3.9/site-packages/pandas/core/algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File /compuworks/anaconda3/envs/kjh/lib/python3.9/site-packages/pandas/core/algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# KeyboardInterrupt:

# %%
ml_left_join_else_data.genres_mt.isna().sum()
# Out:
# 51758

# %%
ml_left_join_else_data = ml_left_join_else_data[~ml_left_join_else_data.genres_mt.isna()]

# %%
ml_left_join_else_data
# Out:
#             userId  movieId  rating            title  genres_ml  genres_mt  \
# 0          ML_1635        1     3.0        Toy Story  Adventure  Animation
# 1          ML_1635        1     3.0        Toy Story  Adventure  Adventure
# 2          ML_1635        1     3.0        Toy Story  Adventure     Comedy
# 3          ML_1635        1     3.0        Toy Story  Adventure     Family
# 4          ML_1635        1     3.0        Toy Story  Adventure    Fantasy
# ...            ...      ...     ...              ...        ...        ...
# 9974097  ML_137662    84944     3.5            Rango    Western    Western
# 9974306  ML_137662    85367     3.0  Just Go with It     Comedy     Comedy
# 9974307  ML_137662    85367     3.0  Just Go with It     Comedy    Romance
# 9974368  ML_137662    85367     3.0  Just Go with It    Romance     Comedy
# 9974369  ML_137662    85367     3.0  Just Go with It    Romance    Romance
#
#         release_year
# 0             1990's
# 1             1990's
# 2             1990's
# 3             1990's
# 4             1990's
# ...              ...
# 9974097       2010's
# 9974306       2010's
# 9974307       2010's
# 9974368       2010's
# 9974369       2010's
#
# [290248 rows x 7 columns]

# %%
ml_left_join_else_data = pd.merge(ml_left_join_else_data, ym_kg_neo4j_data, on=["title", "release_year"], how="left", suffixes=("_ml", "_ym"))

# %%
ml_left_join_else_data = ml_left_join_else_data[["userId_ml", "movieId_ml", "title", "rating_ml", "genres_ml", "genres_mt", "genres", "release_year", "distributor"]]

# %%
ml_left_join_else_data = ml_left_join_else_data.rename(columns={"userId_ml":"userId", "movieId_ml":"movieId", "rating_ml":"rating", "genres":"genres_ym"})

# %%
ml_left_join_else_data.drop_duplicates(inplace=True)

# %%
ml_left_join_else_data.genres_ym.isna().sum()
# Out:
# 124580

# %%
ml_left_join_else_data = ml_left_join_else_data[~ml_left_join_else_data.genres_ym.isna()]

# %%
ml_left_join_else_data
# Out:
#              userId  movieId      title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 807         ML_1635        1  Toy Story     3.0  Adventure  Adventure
# 808         ML_1635        1  Toy Story     3.0  Adventure  Adventure
# ...             ...      ...        ...     ...        ...        ...
# 38297304  ML_137662     3735    Serpico     4.5      Crime      Crime
# 38297327  ML_137662     3735    Serpico     4.5      Crime      Drama
# 38297350  ML_137662     3735    Serpico     4.5      Drama  Biography
# 38297373  ML_137662     3735    Serpico     4.5      Drama      Crime
# 38297396  ML_137662     3735    Serpico     4.5      Drama      Drama
#
#          genres_ym release_year                     distributor
# 0           Comedy       1990's  Buena Vista Distribution Compa
# 1             Kids       1990's  Buena Vista Distribution Compa
# 2           Family       1990's  Buena Vista Distribution Compa
# 807         Comedy       1990's  Buena Vista Distribution Compa
# 808           Kids       1990's  Buena Vista Distribution Compa
# ...            ...          ...                             ...
# 38297304     Drama       1970's                             NaN
# 38297327     Drama       1970's                             NaN
# 38297350     Drama       1970's                             NaN
# 38297373     Drama       1970's                             NaN
# 38297396     Drama       1970's                             NaN
#
# [330786 rows x 9 columns]

# %%
ml_left_join_else_data.drop_duplicates(inplace=True)

# %%
ml_left_join_else_data
# Out:
#              userId  movieId      title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1  Toy Story     3.0  Adventure  Animation
# 807         ML_1635        1  Toy Story     3.0  Adventure  Adventure
# 808         ML_1635        1  Toy Story     3.0  Adventure  Adventure
# ...             ...      ...        ...     ...        ...        ...
# 38297304  ML_137662     3735    Serpico     4.5      Crime      Crime
# 38297327  ML_137662     3735    Serpico     4.5      Crime      Drama
# 38297350  ML_137662     3735    Serpico     4.5      Drama  Biography
# 38297373  ML_137662     3735    Serpico     4.5      Drama      Crime
# 38297396  ML_137662     3735    Serpico     4.5      Drama      Drama
#
#          genres_ym release_year                     distributor
# 0           Comedy       1990's  Buena Vista Distribution Compa
# 1             Kids       1990's  Buena Vista Distribution Compa
# 2           Family       1990's  Buena Vista Distribution Compa
# 807         Comedy       1990's  Buena Vista Distribution Compa
# 808           Kids       1990's  Buena Vista Distribution Compa
# ...            ...          ...                             ...
# 38297304     Drama       1970's                             NaN
# 38297327     Drama       1970's                             NaN
# 38297350     Drama       1970's                             NaN
# 38297373     Drama       1970's                             NaN
# 38297396     Drama       1970's                             NaN
#
# [330786 rows x 9 columns]

# %%
import copy
ml_left_join_else_data_ = copy.deepcopy(ml_left_join_else_data)

# %%
def remove_duplicate_rows(row):
    if row['genres_ml'] == row['genres_mt'] or row['genres_ml'] == row['genres_ym'] or row['genres_mt'] == row['genres_ym']:
        return 0
    return 1

ml_left_join_else_data['duplicate_flag'] = ml_left_join_else_data.apply(remove_duplicate_rows, axis=1)
df_filtered = ml_left_join_else_data[ml_left_join_else_data['duplicate_flag'] == 1]

# %%
df_filtered = df_filtered.drop(columns=['duplicate_flag'])
df_filtered
# Out:
#              userId  movieId       title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1615        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# 1616        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# ...             ...      ...         ...     ...        ...        ...
# 38296965  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38297002  ML_137662      379     Timecop     2.0   Thriller     Sci-Fi
# 38297003  ML_137662      379     Timecop     2.0   Thriller     Sci-Fi
# 38297248  ML_137662     3247  Sister Act     3.5      Crime      Music
# 38297281  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#                 genres_ym release_year                     distributor
# 0                  Comedy       1990's  Buena Vista Distribution Compa
# 1                    Kids       1990's  Buena Vista Distribution Compa
# 2                  Family       1990's  Buena Vista Distribution Compa
# 1615                 Kids       1990's  Buena Vista Distribution Compa
# 1616               Family       1990's  Buena Vista Distribution Compa
# ...                   ...          ...                             ...
# 38296965          Fantasy       1990's                             NaN
# 38297002  Science Fiction       1990's                             NaN
# 38297003          Fantasy       1990's                             NaN
# 38297248           Comedy       1990's                             NaN
# 38297281            Drama       1970's                             NaN
#
# [173410 rows x 9 columns]

# %%
df_filtered["sorted_genres"] = df_filtered[['genres_ml', 'genres_mt', 'genres_ym']].apply(sorted, axis=1)

# %%
df_filtered
# Out:
#              userId  movieId       title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1615        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# 1616        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# ...             ...      ...         ...     ...        ...        ...
# 38296965  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38297002  ML_137662      379     Timecop     2.0   Thriller     Sci-Fi
# 38297003  ML_137662      379     Timecop     2.0   Thriller     Sci-Fi
# 38297248  ML_137662     3247  Sister Act     3.5      Crime      Music
# 38297281  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#                 genres_ym release_year                     distributor  \
# 0                  Comedy       1990's  Buena Vista Distribution Compa
# 1                    Kids       1990's  Buena Vista Distribution Compa
# 2                  Family       1990's  Buena Vista Distribution Compa
# 1615                 Kids       1990's  Buena Vista Distribution Compa
# 1616               Family       1990's  Buena Vista Distribution Compa
# ...                   ...          ...                             ...
# 38296965          Fantasy       1990's                             NaN
# 38297002  Science Fiction       1990's                             NaN
# 38297003          Fantasy       1990's                             NaN
# 38297248           Comedy       1990's                             NaN
# 38297281            Drama       1970's                             NaN
#
#                                 sorted_genres
# 0              [Adventure, Animation, Comedy]
# 1                [Adventure, Animation, Kids]
# 2              [Adventure, Animation, Family]
# 1615                [Adventure, Comedy, Kids]
# 1616              [Adventure, Comedy, Family]
# ...                                       ...
# 38296965         [Fantasy, Romance, Thriller]
# 38297002  [Sci-Fi, Science Fiction, Thriller]
# 38297003          [Fantasy, Sci-Fi, Thriller]
# 38297248               [Comedy, Crime, Music]
# 38297281            [Biography, Crime, Drama]
#
# [173410 rows x 10 columns]

# %%
# 중복 행을 제거하기 위한 함수 정의
def remove_duplicate_rows(row):
    return "|".join(row['sorted_genres'])

# 중복 행을 제거하는 코드 적용
df_filtered['unique_genres'] = df_filtered.apply(remove_duplicate_rows, axis=1)
df_filtered["sorted_genres"] = df_filtered["sorted_genres"].apply(lambda x:"|".join(x))
df_filtered = df_filtered.drop_duplicates(subset=['unique_genres', 'userId', 'movieId', 'title', 'rating', 'release_year'])

# %%
df_filtered
# Out:
#              userId  movieId       title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1615        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# 1616        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# ...             ...      ...         ...     ...        ...        ...
# 38296889  ML_137662      379     Timecop     2.0     Sci-Fi   Thriller
# 38296964  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38296965  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38297248  ML_137662     3247  Sister Act     3.5      Crime      Music
# 38297281  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#                 genres_ym release_year                     distributor  \
# 0                  Comedy       1990's  Buena Vista Distribution Compa
# 1                    Kids       1990's  Buena Vista Distribution Compa
# 2                  Family       1990's  Buena Vista Distribution Compa
# 1615                 Kids       1990's  Buena Vista Distribution Compa
# 1616               Family       1990's  Buena Vista Distribution Compa
# ...                   ...          ...                             ...
# 38296889          Fantasy       1990's                             NaN
# 38296964  Science Fiction       1990's                             NaN
# 38296965          Fantasy       1990's                             NaN
# 38297248           Comedy       1990's                             NaN
# 38297281            Drama       1970's                             NaN
#
#                              sorted_genres                     unique_genres
# 0               Adventure|Animation|Comedy        Adventure|Animation|Comedy
# 1                 Adventure|Animation|Kids          Adventure|Animation|Kids
# 2               Adventure|Animation|Family        Adventure|Animation|Family
# 1615                 Adventure|Comedy|Kids             Adventure|Comedy|Kids
# 1616               Adventure|Comedy|Family           Adventure|Comedy|Family
# ...                                    ...                               ...
# 38296889           Fantasy|Sci-Fi|Thriller           Fantasy|Sci-Fi|Thriller
# 38296964  Romance|Science Fiction|Thriller  Romance|Science Fiction|Thriller
# 38296965          Fantasy|Romance|Thriller          Fantasy|Romance|Thriller
# 38297248                Comedy|Crime|Music                Comedy|Crime|Music
# 38297281             Biography|Crime|Drama             Biography|Crime|Drama
#
# [120703 rows x 11 columns]

# %%
df_filtered = df_filtered.drop(columns=['sorted_genres', 'unique_genres'])
df_filtered
# Out:
#              userId  movieId       title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1615        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# 1616        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# ...             ...      ...         ...     ...        ...        ...
# 38296889  ML_137662      379     Timecop     2.0     Sci-Fi   Thriller
# 38296964  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38296965  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38297248  ML_137662     3247  Sister Act     3.5      Crime      Music
# 38297281  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#                 genres_ym release_year                     distributor
# 0                  Comedy       1990's  Buena Vista Distribution Compa
# 1                    Kids       1990's  Buena Vista Distribution Compa
# 2                  Family       1990's  Buena Vista Distribution Compa
# 1615                 Kids       1990's  Buena Vista Distribution Compa
# 1616               Family       1990's  Buena Vista Distribution Compa
# ...                   ...          ...                             ...
# 38296889          Fantasy       1990's                             NaN
# 38296964  Science Fiction       1990's                             NaN
# 38296965          Fantasy       1990's                             NaN
# 38297248           Comedy       1990's                             NaN
# 38297281            Drama       1970's                             NaN
#
# [120703 rows x 9 columns]

# %%
df_filtered.to_csv("./data/ml_left_join_else_data.csv", index=False)

# %%
def ry(x):
    try:
        return str(int(x // 10 * 10)) + "\'s"
    except:
        return ""

movielens_tmdb_df['release_year'] = movielens_tmdb_df['release_year'].apply(lambda x:ry(x))

# %%
df_filtered
# Out:
#              userId  movieId       title  rating  genres_ml  genres_mt  \
# 0           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2           ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1615        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# 1616        ML_1635        1   Toy Story     3.0  Adventure     Comedy
# ...             ...      ...         ...     ...        ...        ...
# 38296889  ML_137662      379     Timecop     2.0     Sci-Fi   Thriller
# 38296964  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38296965  ML_137662      379     Timecop     2.0   Thriller    Romance
# 38297248  ML_137662     3247  Sister Act     3.5      Crime      Music
# 38297281  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#                 genres_ym release_year                     distributor
# 0                  Comedy       1990's  Buena Vista Distribution Compa
# 1                    Kids       1990's  Buena Vista Distribution Compa
# 2                  Family       1990's  Buena Vista Distribution Compa
# 1615                 Kids       1990's  Buena Vista Distribution Compa
# 1616               Family       1990's  Buena Vista Distribution Compa
# ...                   ...          ...                             ...
# 38296889          Fantasy       1990's                             NaN
# 38296964  Science Fiction       1990's                             NaN
# 38296965          Fantasy       1990's                             NaN
# 38297248           Comedy       1990's                             NaN
# 38297281            Drama       1970's                             NaN
#
# [120703 rows x 9 columns]

# %%
tmdb_ml_left_join_else_data = pd.merge(df_filtered, movielens_tmdb_df, how="left", on=["title", 'release_year']).drop_duplicates()

# %%
tmdb_ml_left_join_else_data.drop(labels=["movieId_y"], inplace=True, axis=1)
tmdb_ml_left_join_else_data.rename(columns={"movieId_x":"movieId"}, inplace=True)

# %%
tmdb_ml_left_join_else_data = tmdb_ml_left_join_else_data.drop_duplicates()

# %%
tmdb_ml_left_join_else_data
# Out:
#            userId  movieId       title  rating  genres_ml  genres_mt  \
# 0         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 3         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 4         ML_1635        1   Toy Story     3.0  Adventure  Animation
# ...           ...      ...         ...     ...        ...        ...
# 249619  ML_137662      379     Timecop     2.0   Thriller    Romance
# 249620  ML_137662     3247  Sister Act     3.5      Crime      Music
# 249621  ML_137662     3247  Sister Act     3.5      Crime      Music
# 249622  ML_137662     3735     Serpico     4.5      Crime  Biography
# 249623  ML_137662     3735     Serpico     4.5      Crime  Biography
#
#        genres_ym release_year                     distributor origin_country  \
# 0         Comedy       1990's  Buena Vista Distribution Compa             US
# 1         Comedy       1990's  Buena Vista Distribution Compa             US
# 2           Kids       1990's  Buena Vista Distribution Compa             US
# 3           Kids       1990's  Buena Vista Distribution Compa             US
# 4         Family       1990's  Buena Vista Distribution Compa             US
# ...          ...          ...                             ...            ...
# 249619   Fantasy       1990's                             NaN             US
# 249620    Comedy       1990's                             NaN             US
# 249621    Comedy       1990's                             NaN             US
# 249622     Drama       1970's                             NaN            NaN
# 249623     Drama       1970's                             NaN            NaN
#
#               Writer Original Story Original Film Writer        Director  \
# 0                NaN    Pete Docter                  NaN   John Lasseter
# 1                NaN    Pete Docter                  NaN   John Lasseter
# 2                NaN    Pete Docter                  NaN   John Lasseter
# 3                NaN    Pete Docter                  NaN   John Lasseter
# 4                NaN    Pete Docter                  NaN   John Lasseter
# ...              ...            ...                  ...             ...
# 249619           NaN            NaN                  NaN     Peter Hyams
# 249620  Paul Rudnick            NaN                  NaN  Emile Ardolino
# 249621  Paul Rudnick            NaN                  NaN  Emile Ardolino
# 249622           NaN            NaN                  NaN    Sidney Lumet
# 249623           NaN            NaN                  NaN    Sidney Lumet
#
#                  cast
# 0           Tom Hanks
# 1         Annie Potts
# 2           Tom Hanks
# 3         Annie Potts
# 4           Tom Hanks
# ...               ...
# 249619   Bruce McGill
# 249620  Harvey Keitel
# 249621   Maggie Smith
# 249622      Al Pacino
# 249623   James Tolkan
#
# [249624 rows x 15 columns]

# %%
tmdb_ml_left_join_else_data.drop_duplicates(subset=["userId", "movieId"])
# Out:
#            userId  movieId                                  title  rating  \
# 0         ML_1635        1                              Toy Story     3.0
# 62        ML_1635        2                                Jumanji     3.0
# 92        ML_1635       22                                Copycat     2.0
# 104       ML_1635       44                          Mortal Kombat     3.0
# 132       ML_1635      110                             Braveheart     2.0
# ...           ...      ...                                    ...     ...
# 249584  ML_137324     2338  I Still Know What You Did Last Summer     2.5
# 249592  ML_137324     3155                      Anna and the King     1.0
# 249596  ML_137662      379                                Timecop     2.0
# 249620  ML_137662     3247                             Sister Act     3.5
# 249622  ML_137662     3735                                Serpico     4.5
#
#         genres_ml  genres_mt        genres_ym release_year  \
# 0       Adventure  Animation           Comedy       1990's
# 62      Adventure     Family             Kids       1990's
# 92          Crime    Mystery            Drama       1990's
# 104        Action  Adventure  Science Fiction       1990's
# 132        Action  Biography        Adventure       1990's
# ...           ...        ...              ...          ...
# 249584     Horror    Mystery         Suspense       1990's
# 249592      Drama     Comedy          Romance       1990's
# 249596     Action    Romance  Science Fiction       1990's
# 249620      Crime      Music           Comedy       1990's
# 249622      Crime  Biography            Drama       1970's
#
#                            distributor origin_country        Writer  \
# 0       Buena Vista Distribution Compa             US           NaN
# 62                                 NaN             US           NaN
# 92                                 NaN             US           NaN
# 104                                NaN             US           NaN
# 132                 Paramount Pictures             GB           NaN
# ...                                ...            ...           ...
# 249584                Columbia Tristar            NaN           NaN
# 249592           Twentieth Century Fox             US           NaN
# 249596                             NaN             US           NaN
# 249620                             NaN             US  Paul Rudnick
# 249622                             NaN            NaN           NaN
#
#        Original Story Original Film Writer             Director  \
# 0         Pete Docter                  NaN        John Lasseter
# 62                NaN                  NaN         Joe Johnston
# 92                NaN                  NaN            Jon Amiel
# 104               NaN                  NaN  Paul W. S. Anderson
# 132               NaN                  NaN           Mel Gibson
# ...               ...                  ...                  ...
# 249584            NaN                  NaN         Danny Cannon
# 249592            NaN                  NaN         Andy Tennant
# 249596            NaN                  NaN          Peter Hyams
# 249620            NaN                  NaN       Emile Ardolino
# 249622            NaN                  NaN         Sidney Lumet
#
#                          cast
# 0                   Tom Hanks
# 62             Robin Williams
# 92           Sigourney Weaver
# 104              Frank Welker
# 132                Mel Gibson
# ...                       ...
# 249584             Jack Black
# 249592           Jodie Foster
# 249596  Jean-Claude Van Damme
# 249620          Harvey Keitel
# 249622              Al Pacino
#
# [14741 rows x 15 columns]

# %%
tmdb_ml_left_join_else_data[tmdb_ml_left_join_else_data.origin_country == "US"]
# Out:
#            userId  movieId       title  rating  genres_ml  genres_mt  \
# 0         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 1         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 2         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 3         ML_1635        1   Toy Story     3.0  Adventure  Animation
# 4         ML_1635        1   Toy Story     3.0  Adventure  Animation
# ...           ...      ...         ...     ...        ...        ...
# 249617  ML_137662      379     Timecop     2.0   Thriller    Romance
# 249618  ML_137662      379     Timecop     2.0   Thriller    Romance
# 249619  ML_137662      379     Timecop     2.0   Thriller    Romance
# 249620  ML_137662     3247  Sister Act     3.5      Crime      Music
# 249621  ML_137662     3247  Sister Act     3.5      Crime      Music
#
#               genres_ym release_year                     distributor  \
# 0                Comedy       1990's  Buena Vista Distribution Compa
# 1                Comedy       1990's  Buena Vista Distribution Compa
# 2                  Kids       1990's  Buena Vista Distribution Compa
# 3                  Kids       1990's  Buena Vista Distribution Compa
# 4                Family       1990's  Buena Vista Distribution Compa
# ...                 ...          ...                             ...
# 249617  Science Fiction       1990's                             NaN
# 249618          Fantasy       1990's                             NaN
# 249619          Fantasy       1990's                             NaN
# 249620           Comedy       1990's                             NaN
# 249621           Comedy       1990's                             NaN
#
#        origin_country        Writer Original Story Original Film Writer  \
# 0                  US           NaN    Pete Docter                  NaN
# 1                  US           NaN    Pete Docter                  NaN
# 2                  US           NaN    Pete Docter                  NaN
# 3                  US           NaN    Pete Docter                  NaN
# 4                  US           NaN    Pete Docter                  NaN
# ...               ...           ...            ...                  ...
# 249617             US           NaN            NaN                  NaN
# 249618             US           NaN            NaN                  NaN
# 249619             US           NaN            NaN                  NaN
# 249620             US  Paul Rudnick            NaN                  NaN
# 249621             US  Paul Rudnick            NaN                  NaN
#
#               Director                   cast
# 0        John Lasseter              Tom Hanks
# 1        John Lasseter            Annie Potts
# 2        John Lasseter              Tom Hanks
# 3        John Lasseter            Annie Potts
# 4        John Lasseter              Tom Hanks
# ...                ...                    ...
# 249617     Peter Hyams           Bruce McGill
# 249618     Peter Hyams  Jean-Claude Van Damme
# 249619     Peter Hyams           Bruce McGill
# 249620  Emile Ardolino          Harvey Keitel
# 249621  Emile Ardolino           Maggie Smith
#
# [191694 rows x 15 columns]

# %%
sample_movie_list = ["Toy Story", "X-Men", "Mission: Impossible", "Schindler's List", "Forrest Gump"]

# %%
tmdb_ml_left_join_else_data[tmdb_ml_left_join_else_data.title.isin(sample_movie_list)][["movieId", "title", "genres_ml", "genres_mt", "genres_ym"]].drop_duplicates()
# Out:
#       movieId                title  genres_ml  genres_mt        genres_ym
# 0           1            Toy Story  Adventure  Animation           Comedy
# 2           1            Toy Story  Adventure  Animation             Kids
# 4           1            Toy Story  Adventure  Animation           Family
# 6           1            Toy Story  Adventure     Comedy             Kids
# 8           1            Toy Story  Adventure     Comedy           Family
# 10          1            Toy Story  Adventure     Family             Kids
# 12          1            Toy Story  Adventure    Fantasy           Comedy
# 14          1            Toy Story  Adventure    Fantasy             Kids
# 16          1            Toy Story  Adventure    Fantasy           Family
# 18          1            Toy Story  Animation     Comedy             Kids
# 20          1            Toy Story  Animation     Comedy           Family
# 22          1            Toy Story  Animation     Family             Kids
# 24          1            Toy Story  Animation    Fantasy           Comedy
# 26          1            Toy Story  Animation    Fantasy             Kids
# 28          1            Toy Story  Animation    Fantasy           Family
# 30          1            Toy Story   Children  Animation           Comedy
# 32          1            Toy Story   Children  Animation             Kids
# 34          1            Toy Story   Children  Animation           Family
# 36          1            Toy Story   Children  Adventure           Comedy
# 38          1            Toy Story   Children  Adventure             Kids
# 40          1            Toy Story   Children  Adventure           Family
# 42          1            Toy Story   Children     Comedy             Kids
# 44          1            Toy Story   Children     Comedy           Family
# 46          1            Toy Story   Children     Family             Kids
# 48          1            Toy Story   Children    Fantasy           Comedy
# 50          1            Toy Story   Children    Fantasy             Kids
# 52          1            Toy Story   Children    Fantasy           Family
# 54          1            Toy Story     Comedy     Family             Kids
# 56          1            Toy Story     Comedy    Fantasy             Kids
# 58          1            Toy Story     Comedy    Fantasy           Family
# 60          1            Toy Story    Fantasy     Family             Kids
# 442       356         Forrest Gump     Comedy    Romance            Drama
# 444       356         Forrest Gump        War    Romance            Drama
# 878       527     Schindler's List        War  Biography            Drama
# 880       527     Schindler's List        War    History            Drama
# 1897      648  Mission: Impossible     Action  Adventure         Thriller
# 1899      648  Mission: Impossible    Mystery     Action        Adventure
# 1901      648  Mission: Impossible    Mystery     Action         Thriller
# 1903      648  Mission: Impossible    Mystery  Adventure         Thriller
# 2893     3793                X-Men     Action  Adventure  Science Fiction
# 2895     3793                X-Men     Action  Adventure          Fantasy
# 2897     3793                X-Men     Action     Sci-Fi        Adventure
# 2899     3793                X-Men     Action     Sci-Fi  Science Fiction
# 2901     3793                X-Men     Action     Sci-Fi          Fantasy
# 2903     3793                X-Men  Adventure     Sci-Fi  Science Fiction
# 2905     3793                X-Men  Adventure     Sci-Fi          Fantasy

# %%
sample_movie_list = ["Toy Story", "X-Men", "Mission: Impossible", "Forrest Gump"]
final_sample = tmdb_ml_left_join_else_data[tmdb_ml_left_join_else_data.title.isin(sample_movie_list)]

# %%
ratio = 0.02

# %%
uid_list = list(final_sample.userId.unique())

# %%
sample_uid_list = random.sample(uid_list, round(len(uid_list) * ratio))
sample_uid_list
# Out:
# ['ML_113198', 'ML_8135', 'ML_120660', 'ML_128425']

# %%
final_sample
# Out:
#            userId  movieId      title  rating  genres_ml  genres_mt genres_ym  \
# 0         ML_1635        1  Toy Story     3.0  Adventure  Animation    Comedy
# 1         ML_1635        1  Toy Story     3.0  Adventure  Animation    Comedy
# 2         ML_1635        1  Toy Story     3.0  Adventure  Animation      Kids
# 3         ML_1635        1  Toy Story     3.0  Adventure  Animation      Kids
# 4         ML_1635        1  Toy Story     3.0  Adventure  Animation    Family
# ...           ...      ...        ...     ...        ...        ...       ...
# 249495  ML_137324        1  Toy Story     5.0     Comedy    Fantasy      Kids
# 249496  ML_137324        1  Toy Story     5.0     Comedy    Fantasy    Family
# 249497  ML_137324        1  Toy Story     5.0     Comedy    Fantasy    Family
# 249498  ML_137324        1  Toy Story     5.0    Fantasy     Family      Kids
# 249499  ML_137324        1  Toy Story     5.0    Fantasy     Family      Kids
#
#        release_year                     distributor origin_country Writer  \
# 0            1990's  Buena Vista Distribution Compa             US    NaN
# 1            1990's  Buena Vista Distribution Compa             US    NaN
# 2            1990's  Buena Vista Distribution Compa             US    NaN
# 3            1990's  Buena Vista Distribution Compa             US    NaN
# 4            1990's  Buena Vista Distribution Compa             US    NaN
# ...             ...                             ...            ...    ...
# 249495       1990's  Buena Vista Distribution Compa             US    NaN
# 249496       1990's  Buena Vista Distribution Compa             US    NaN
# 249497       1990's  Buena Vista Distribution Compa             US    NaN
# 249498       1990's  Buena Vista Distribution Compa             US    NaN
# 249499       1990's  Buena Vista Distribution Compa             US    NaN
#
#        Original Story Original Film Writer       Director         cast
# 0         Pete Docter                  NaN  John Lasseter    Tom Hanks
# 1         Pete Docter                  NaN  John Lasseter  Annie Potts
# 2         Pete Docter                  NaN  John Lasseter    Tom Hanks
# 3         Pete Docter                  NaN  John Lasseter  Annie Potts
# 4         Pete Docter                  NaN  John Lasseter    Tom Hanks
# ...               ...                  ...            ...          ...
# 249495    Pete Docter                  NaN  John Lasseter  Annie Potts
# 249496    Pete Docter                  NaN  John Lasseter    Tom Hanks
# 249497    Pete Docter                  NaN  John Lasseter  Annie Potts
# 249498    Pete Docter                  NaN  John Lasseter    Tom Hanks
# 249499    Pete Docter                  NaN  John Lasseter  Annie Potts
#
# [10014 rows x 15 columns]

# %%
final_sample = final_sample[final_sample['userId'].isin(sample_uid_list)]
final_sample.to_csv("./data/final_sample_tmdb_ml_left_join_else_data.csv", index=False)
